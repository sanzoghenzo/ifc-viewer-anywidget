# %%
import ifcopenshell

model = ifcopenshell.open("house.ifc")
model.schema
# Out:
# 'IFC4'

# %%
from ifc_anywidget import IfcViewer

viewer = IfcViewer(ifc_model=model)
viewer

# %%
[model.by_guid(gid).get_info() for gid in viewer.selected_guids if gid]
# Out:
# []
